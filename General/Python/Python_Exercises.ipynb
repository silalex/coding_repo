# %% [markdown]
# ## 1. Two Sum = K (return INDXes of all matched pairs)
# ```
# Task: Return indices of two numbers that add up to target K.
# Source: LeetCode — None
#
# Given an array of integers nums and an integer target, return ALL POSSIBLE(!) pairs of indices of the two numbers such that they add up to target.
#
# You can return the answer in any order.
#
# Example:
# Input: nums = [30, 50, 0, 30, 5, 40, 30], target = 60
# Output: [(0,3), (0,6), (3,6)]
#
# Explanation: Because nums[0] + nums[3] == 60, nums[0] + nums[6] == 60, and nums[3] + nums[6] == 60 we return [(0,3),(0,6),(3,6)].
# ```

# %%
from typing import List, Tuple

def all_pairs_sum_60(nums: List[int], target: int) -> List[Tuple[int, int]]:
    pass

# Test Case:
test_nums = [30, 50, 0, 30, 5, 40, 30]
target = 60
print(all_pairs_sum_60(test_nums, target))  # Expected output: [(0, 3), (0, 6), (3,6)]
# Out:
# None

# %% [markdown]
# ## 2. Two Sum <= K (return INDXes of all matched pairs)
# ```
# Task: Return indices of two numbers that sum <= target.
#
# Given an array of integers nums and an integer target, return ALL POSSIBLE(!) pairs of indices of the two numbers such that they add < target.
#
# You can return the answer in any order.
#
# Example:
# Input: nums = [3, 5, 2, 8, 7], target = 10
# Output:  [(0, 1), (0, 2), (0, 4), (1, 2), (2, 3), (2,4)]
# ```

# %%
from typing import List, Tuple

def twoSumAllPairsLE(nums: List[int], target: int) -> List[Tuple[int, int]]:
    pass

# Test case
nums = [3, 5, 2, 8, 7]
target = 10
print(twoSumAllPairsLE(nums, target))  # Expected output: [(0, 1), (0, 2), (0, 4), (1, 2), (2, 3), (2,4)]
# Out:
# None

# %% [markdown]
# ## 3. Two Sum = K (return IDXs of the 1st matched pair)
# ```
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
# Example:
# Input: nums = [3, 2, 4], target = 6
# Output: [1, 2]
# ```

# %%
# Solution: One-Pass Hash Map / Complement Lookup - Time complexity: O(n) / Space complexity: O(n)
def twoSum(nums: List[int], target: int) -> List[int]:
    pass    

# Test case:
nums = [3, 2, 4]
target = 6
print(twoSum(nums, target))
# Out:
# None
