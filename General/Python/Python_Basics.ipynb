# %%
[1,2,3] == [1,2,3]
# Out:
# True

# %%
[1,2,3] == [3,2,1]
# Out:
# False

# %%
[1,2,3] is [1,2,3]
# Out:
# False

# %%
records = [
    frozenset(["red", "blue"]),
    frozenset(["blue", "red"]),
    frozenset(["green"])
]

unique = set(records)
print(unique)
# Out:
# {frozenset({'blue', 'red'}), frozenset({'green'})}
