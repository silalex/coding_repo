# %% [markdown]
# ## 3Sum
# ```
# Solution
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.
#
# Notice that the solution set must not contain duplicate triplets.
#
# Example 1:
# Input: nums = [-1,0,1,2,-1,-4]
# Output: [[-1,-1,2],[-1,0,1]]
#
# Explanation:
# nums[0] + nums[1] + nums[2] = (-1) + 0 + 1 = 0.
# nums[1] + nums[2] + nums[4] = 0 + 1 + (-1) = 0.
# nums[0] + nums[3] + nums[4] = (-1) + 2 + (-1) = 0.
# The distinct triplets are [-1,0,1] and [-1,-1,2].
#
# Notice that the order of the output and the order of the triplets does not matter.
#
# Example 2:
# Input: nums = [0,1,1]
# Output: []
#
# Explanation: The only possible triplet does not sum up to 0.
#
# Example 3:
# Input: nums = [0,0,0]
# Output: [[0,0,0]]
#
# Explanation: The only possible triplet sums up to 0.
# ```

# %%
def get_three_sum(nums: List[int]) -> List[List[int]]:
    # Sort the array to easily manage duplicates and use the two-pointer approach
    nums.sort()
    n = len(nums)
    answer = []

    # Iterate through the array to select the first element 'a'
    for i in range(n):
        # Optimization: If the current number is positive, we can stop
        # since all remaining numbers are positive and cannot sum to zero
        if nums[i] > 0:
            break
        # Skip duplicate values for the first element to avoid duplicate triplets
        if i > 0 and nums[i] == nums[i-1]:
            continue

        # Use two pointers for the remaining sub-array to find 'b' and 'c'
        lo, hi = i + 1, n - 1
        while lo < hi:
            summ = nums[i] + nums[lo] + nums[hi]

            if summ == 0:
                # Found a triplet that sums to zero
                answer.append([nums[i], nums[lo], nums[hi]])
                # Move pointers inward
                lo += 1
                hi -= 1
                # Skip duplicates for the second and third elements
                while lo < hi and nums[lo] == nums[lo-1]:
                    lo += 1
                while lo < hi and nums[hi] == nums[hi+1]:
                    hi -= 1
            elif summ < 0:
                # Sum is too low, increment the left pointer to increase the sum
                lo += 1
            else:
                # Sum is too high, decrement the right pointer to decrease the sum
                hi -= 1

    return answer

# %%
# Example usage:
print(get_three_sum([-1, 0, 1, 2, -1, -4]))  # Output: [[-1, -1, 2], [-1, 0, 1]]
# Out:
# [[-1, -1, 2], [-1, 0, 1]]
